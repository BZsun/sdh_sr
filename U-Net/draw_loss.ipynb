# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

loss_data = pd.read_csv('/home/jovyan/cache/res_train_1/loss.csv')
index = loss_data[0:]

plt.title('Loss Record')
plt.plot(index['epoch'], index['loss_img'], color='green', label='loss_img')
# plt.plot(index['epoch'], index['loss_hr'], color='red', label='loss_hr')
# plt.plot(index['epoch'], index['loss_textures'],  color='skyblue', label='loss_textures')
# plt.plot(index['epoch'], index['loss_img'], color='loss_img', label='loss_img')
# plt.plot(index['epoch'], index['loss'], color='loss', label='loss')
plt.legend() # 显示图例

plt.xticks(range(0,50000,10000))
plt.xlabel('epoch')
plt.ylabel('loss value')
plt.show()
